# %%
# Modules to Import

import pandas as pd
from EvaluateChatBot import EvalChatBot
from ChatBot import ChatBot

from datasets import Dataset, Features, Sequence, Value
from ragas import evaluate
import ast

NUMBER_OF_QUESTION = 50
# import time
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
    context_recall,
    context_precision
)

# %%
# test_set_df
uploaded_file = "../../pdfData/Cells and Chemistry of Life.pdf"

# %%
#! NOTE: ONLY USE WHEN YOU WANT TO GENERATE NEW QUESTION AND ANSWER!
#list_of_eval_question_answer = EvalChatBot(uploaded_file,NUMBER_OF_QUESTION)
# questionList = []
# answerList = []
# contextList = []

# for question_answer in list_of_eval_question_answer:
#     questionList.append(question_answer['question'])
#     answerList.append(question_answer['answer'])
#     contextList.append(question_answer['contexts'])
#list_of_eval_question_answer[4]['contexts'] #! look at each question and search google for ground_truth answer!
#! ONLY RUN WHEN YOU WANT TO GENERATE TESTSET!
# df = pd.DataFrame({'question': questionList, 'answer': answerList, 'contexts': contextList})
# df.to_csv("./testSet.csv", index=False)

# %%
df = pd.read_csv("./testSet.csv")
#df['ground_truth'] = ground_truthList
questionList = df['question']
answerList = df['answer']
contextList = df['contexts']

# print(questionList[99])

# %%
#! ONLY RUN THIS CELL WHEN YOU WANT TO GENERATE TESTSET
# i = 49
# with open("./doingTestSet.txt", 'w', encoding='utf8') as file:
#     file.writelines("Answer this question based on this context only. I want to turn your answer become my ground_truth so I can achive above 90 percents ragas score. Answer in 40 words only" + "\n")
#     file.writelines("question: " + str(questionList[i]) + "\n")
#     file.writelines("answer : " + str(answerList[i]) + "\n")
#     file.writelines("context: " + str(contextList[i]))
# print("question: " + str(questionList[4]))
# print("context: " + str(contextList[4]))

# %%
#! after a while i self build my own testset
ground_truthList = []
with open('./ground_truth.txt', 'r') as file:
    a = file.readlines()
for groundTruth in a:
    ground_truthList.append(groundTruth)
ground_truthList[4]
# Out:
# 'Two key differences visible under a light microscope are: (a) plant cells have a cell wall and chloroplasts, whereas animal cells do not. (b) Plant cells possess a large central vacuole, unlike animal cells, which have smaller vacuoles.\n'

# %%
df = pd.read_csv("./testSet.csv")
#df['ground_truth'] = ground_truthList
questionList = df['question']
answerList = df['answer']
contextList = df['contexts']

# %%
contextListConvertedEleToList = [ast.literal_eval(context) for context in contextList]

# %%
type(contextListConvertedEleToList[0])
# Out:
# list

# %%
len(df)
# Out:
# 50

# %%
new_df = df
new_df['ground_truth'] = ground_truthList
new_df
# Out:
#                                              question  \
# 0   What are some of the different parts of a cell...
# 1   What are the three main parts that make up the...
# 2   What are the main functions of the Golgi body ...
# 3   What is the difference between a plant cell an...
# 4   What are two key differences between plant cel...
# 5   Why do different types of cells have different...
# 6   How can plant tissue culture help improve the ...
# 7   How are red blood cells adapted to deliver oxy...
# 8   What is the role of the cell membrane in contr...
# 9   How does diffusion work and what factors affec...
# 10   Why is diffusion important for living organisms?
# 11                     Why are cells typically small?
# 12  How are root hair cells and epithelial cells i...
# 13  What is osmosis and how does it affect plant a...
# 14  Why is NEWater an important source of water fo...
# 15  Why is turgor important in plants and how does...
# 16  How can we show osmosis in living tissues usin...
# 17  Why is energy required for active transport to...
# 18  What is the process that causes water in the b...
# 19  Why do marathon runners need to eat a lot of c...
# 20  What is the difference between single sugars a...
# 21  Why do we need to test for reducing sugars in ...
# 22  What are some functions of carbohydrates in ou...
# 23  Why do some animals have a thick layer of fat ...
# 24  What is the ethanol emulsion test used for in ...
# 25  What are the sources of proteins and what are ...
# 26  Do you think it's important to have a good und...
# 27  Why are soldiers in the Arctic recommended a d...
# 28  What are enzymes and how do they help speed up...
# 29  What are some examples of digestive enzymes an...
# 30  Why are enzymes named according to a scientifi...
# 31  Why is the shape of an enzyme important for it...
# 32  How does temperature affect the rate of enzyme...
# 33  How are enzymes affected by pH levels and why ...
# 34  What is the purpose of the experiment describe...
# 35  What are some of the functions of different pa...
# 36  What are the three main parts of a plant cell ...
# 37  What is the function of the rough endoplasmic ...
# 38  What is the difference between a plant cell an...
# 39  What are two differences between plant cells a...
# 40  Why do some cells have different shapes and st...
# 41  How can plant tissue culture help improve the ...
# 42  How are red blood cells and root hair cells ad...
# 43  What is the role of the cell membrane in contr...
# 44  What is diffusion and how does it play a role ...
# 45  Why is it important for living organisms to ha...
# 46             Why are cells typically small in size?
# 47  How are root hair cells and epithelial cells i...
# 48  What is osmosis and how does it affect plant a...
# 49  Why is NEWater an important source of water fo...
#
#                                                answer  \
# 0    The different parts of a cell include the cel...
# 1    There is no information provided in the given...
# 2    The main functions of the Golgi body in a cel...
# 3    The main differences between plant and animal...
# 4    (a) The cell membrane, cytoplasm, nucleus, an...
# 5    Different types of cells have different shape...
# 6                                      I do not know.
# 7    Red blood cells are adapted to deliver oxygen...
# 8    The cell membrane controls the movement of su...
# 9    Diffusion is the process of particles moving ...
# 10   Diffusion is important for living organisms b...
# 11   Cells are typically small in order to facilit...
# 12   Root hair cells and epithelial cells in the s...
# 13   Osmosis is the diffusion of water molecules a...
# 14   NEWater is an important source of water for S...
# 15   Turgor is important in plants because it help...
# 16   Refer to Experiment 2C of the Practical Workb...
# 17   Energy is required for active transport to en...
# 18   There is no relevant information in this port...
# 19   Marathon runners need to eat a lot of carbohy...
# 20   Single sugars are the basic unit of carbohydr...
# 21   Adding amylase to a starch solution will brea...
# 22   Carbohydrates have multiple functions in both...
# 23   Some animals have a thick layer of fat under ...
# 24   The ethanol emulsion test is not mentioned in...
# 25   Proteins are commonly found in animal foods s...
# 26   The Arctic diet is rich in fats, as they are ...
# 27                                      I don't know.
# 28   Enzymes are proteins that act as biological c...
# 29   Some examples of digestive enzymes are amylas...
# 30   Enzymes are named according to a scientific s...
# 31   The shape of an enzyme is important for its f...
# 32   Increasing the temperature increases the rate...
# 33   Enzymes can be affected by pH levels, as chan...
# 34   The purpose of the experiment is to investiga...
# 35   Mitochondria provide energy for cell activiti...
# 36   (a) cell membrane (b) nucleus (c) mitochondri...
# 37   The rough endoplasmic reticulum is responsibl...
# 38   In terms of their structure, plant cells have...
# 39   A visible difference between plant cells and ...
# 40   Cells have different shapes and structures to...
# 41                                      I don't know.
# 42   The root hair cell and the red blood cell are...
# 43   The cell membrane controls the movement of su...
# 44   Diffusion is the movement of particles from a...
# 45   A high rate of diffusion is important for liv...
# 46   Cells are typically small in size because the...
# 47   Root hair cells and epithelial cells in the s...
# 48   Osmosis is the movement of water molecules fr...
# 49                                      I don't know.
#
#                                              contexts  \
# 0   ['2 Chapter 1 Cells and the Chemistry of LifeC...
# 1   ['4 Chapter 1 Cells and the Chemistry of LifeC...
# 2   ['6 Chapter 1 Cells and the Chemistry of LifeC...
# 3   ['10 Chapter 1 Cells and the Chemistry of Life...
# 4   ['10 Chapter 1 Cells and the Chemistry of Life...
# 5   ['12 Chapter 1 Cells and the Chemistry of Life...
# 6   ["14 Chapter 1 Cells and the Chemistry of Life...
# 7   ['12 Chapter 1 Cells and the Chemistry of Life...
# 8   ['22 Chapter 2 Cells and the Chemistry of Life...
# 9   ['20 Chapter 2 Cells and the Chemistry of Life...
# 10  ['20 Chapter 2 Cells and the Chemistry of Life...
# 11  ['26 Chapter 2 Cells and the Chemistry of Life...
# 12  ['26 Chapter 2 Cells and the Chemistry of Life...
# 13  ['30 Chapter 2 Cells and the Chemistry of Life...
# 14  ['30 Chapter 2 Cells and the Chemistry of Life...
# 15  ['32 Chapter 2 Cells and the Chemistry of Life...
# 16  ['34 Chapter 2 Cells and the Chemistry of Life...
# 17  ['36 Chapter 2 Cells and the Chemistry of Life...
# 18  ["38 Chapter 2 Cells and the Chemistry of Life...
# 19  ['What You Will Learn• What are carbohydrates?...
# 20  ['42 Chapter 3 Cells and the Chemistry of Life...
# 21  ['44 Chapter 3 Cells and the Chemistry of Life...
# 22  ['What You Will Learn• What are carbohydrates?...
# 23  ['48 Chapter 3 Cells and the Chemistry of Life...
# 24  ['50 Chapter 3 Cells and the Chemistry of Life...
# 25  ["Chapter 3 Cells and the Chemistry of Life 52...
# 26  ["Chapter 3 Cells and the Chemistry of Life No...
# 27  ['56 Chapter 3 Cells and the Chemistry of Life...
# 28  ['58 Chapter 4 Cells and the Chemistry of Life...
# 29  ['Chapter 4 Cells and the Chemistry of LifeEnz...
# 30  ['62 Chapter 4 Cells and the Chemistry of Life...
# 31  ['64 Chapter 4 Cells and the Chemistry of Life...
# 32  ['66 Chapter 4 Cells and the Chemistry of Life...
# 33  ["68 Chapter 4 Cells and the Chemistry of Life...
# 34  ["70 Chapter 4 Cells and the Chemistry of Life...
# 35  ['8 Chapter 1 Cells and the Chemistry of LifeC...
# 36  ['4 Chapter 1 Cells and the Chemistry of LifeC...
# 37  ['6 Chapter 1 Cells and the Chemistry of LifeC...
# 38  ['10 Chapter 1 Cells and the Chemistry of Life...
# 39  ['10 Chapter 1 Cells and the Chemistry of Life...
# 40  ['12 Chapter 1 Cells and the Chemistry of Life...
# 41  ["14 Chapter 1 Cells and the Chemistry of Life...
# 42  ['12 Chapter 1 Cells and the Chemistry of Life...
# 43  ['22 Chapter 2 Cells and the Chemistry of Life...
# 44  ['20 Chapter 2 Cells and the Chemistry of Life...
# 45  ['22 Chapter 2 Cells and the Chemistry of Life...
# 46  ['26 Chapter 2 Cells and the Chemistry of Life...
# 47  ['26 Chapter 2 Cells and the Chemistry of Life...
# 48  ['30 Chapter 2 Cells and the Chemistry of Life...
# 49  ['30 Chapter 2 Cells and the Chemistry of Life...
#
#                                          ground_truth
# 0   Cells consist of various parts: the cell wall ...
# 1   The protoplasm of a cell is composed of the ce...
# 2   The Golgi body chemically modifies substances ...
# 3   Plant cells have a cell wall, chloroplasts for...
# 4   Two key differences visible under a light micr...
# 5   Different cell types have varied shapes and st...
# 6                          I don't know the answer.\n
# 7   Red blood cells deliver oxygen efficiently by ...
# 8   The cell membrane regulates the movement of su...
# 9   Diffusion is the movement of particles from hi...
# 10  Diffusion is crucial for living organisms as i...
# 11  Cells are typically small because a higher sur...
# 12  Root hair cells and epithelial cells in the sm...
# 13  Osmosis is the diffusion of water through a pa...
# 14  NEWater is crucial for Singapore as it provide...
# 15  Turgor is crucial for plant structure as it ma...
# 16  To show osmosis in living tissues using a pota...
# 17  Energy is essential for active transport becau...
# 18  There is no relevant information in this porti...
# 19  Marathon runners eat a lot of carbohydrates be...
# 20  Single sugars are basic carbohydrate units tha...
# 21  Testing for reducing sugars with Benedict's so...
# 22  Carbohydrates in our bodies provide energy, fo...
# 23  Animals with a thick layer of fat under their ...
# 24  The ethanol emulsion test detects fats in food...
# 25  Proteins are sourced from animal foods like me...
# 26  Yes, The Arctic diet is rich in fats, as they ...
# 27                         I don't know the answer.\n
# 28  Enzymes are proteins that act as biological ca...
# 29  Digestive enzymes include amylase (starch to m...
# 30  Enzymes are named using the 'International Uni...
# 31  The shape of an enzyme is crucial because it a...
# 32  Increasing temperature enhances enzyme activit...
# 33  Enzymes' activity varies with pH; deviations f...
# 34  The experiment aims to test how pH influences ...
# 35  Mitochondria generate energy through aerobic r...
# 36  The three main parts of a plant cell are the c...
# 37  The rough endoplasmic reticulum is responsible...
# 38  Plant cells have a cell wall, large central va...
# 39  Under a light microscope, plant cells have a d...
# 40  Cells have different shapes and structures bec...
# 41                         I don't know the answer.\n
# 42  Red blood cells and root hair cells are adapte...
# 43  The cell membrane is partially permeable, cont...
# 44  Diffusion is the movement of particles from a ...
# 45  A high rate of diffusion is crucial for living...
# 46  Cells are small to maintain a high surface are...
# 47  Root hair cells and epithelial cells in the sm...
# 48  Osmosis is the movement of water from a high t...
# 49                            I dont know the answer.

# %%
# Ensure your contexts are lists of strings
data = {
    "question": questionList, #! replace with question list!
    "answer": answerList,  #! replace with response from chatbot
    "contexts": contextListConvertedEleToList,  
    "ground_truth": ground_truthList #! replace with response from EvaluateChatbot
}

# Define the features explicitly to ensure correct data types
features = Features({
    "question": Value("string"),
    "answer": Value("string"),
    "contexts": Sequence(Value("string")),  # Ensuring contexts is treated as a sequence of strings
    "ground_truth": Value("string")
})

# Convert the dictionary to a Dataset with the specified features
dataset = Dataset.from_dict(data, features=features)

# Perform the evaluation using the adjusted dataset
result = evaluate(
    dataset,
    metrics=[
        context_precision,
        faithfulness,
        answer_relevancy,
        context_recall
    ],
)

print(result)
# Out:
# Evaluating:   0%|          | 0/200 [00:00<?, ?it/s]
# {'context_precision': 0.8667, 'faithfulness': 0.7577, 'answer_relevancy': 0.8195, 'context_recall': 0.8900}
